# %%
import numpy as np

# %%
data = np.loadtxt(fname='./inflammation-01.csv',delimiter=",")

# %%
print(data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
import matplotlib.pyplot as plt

# %%
image = plt.imshow(data)
plt.show()

# %%
ave_information = np.mean(data, axis=0)
ave_plot = plt.plot(ave_information)
plt.xlabel('time(days)')
plt.ylabel('inflammation score')
plt.title('patient data')
plt.show()

# %%
max_plot = plt.plot(np.max(data, axis=0))
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 3.0))

sbplt1 = fig.add_subplot(1, 3, 1)
sbplt2 = fig.add_subplot(1, 3, 2)
sbplt3 = fig.add_subplot(1, 3, 3)

sbplt1.set_ylabel('average')
sbplt1.plot(np.mean(data, axis=0))

sbplt2.set_xlabel('time(days)')

sbplt2.set_ylabel('max')
sbplt2.plot(np.max(data, axis=0), '--')

sbplt3.set_ylabel('min')
sbplt3.plot(np.min(data, axis=0))

fig.tight_layout()
plt.show()

# %%
word = 'lead'
print(word)
# Out:
# lead

# %%
print (word[0])
# Out:
# l

# %%
for char in word:
    print(char)
# Out:
# l
# e
# a
# d

# %%
for char in word:
    print("hi", char)
# Out:
# hi l
# hi e
# hi a
# hi d

# %%
length = 0
for vowel in 'aeiou':
    length = length + 1

print('There are', length, 'vowels.')
# Out:
# There are 5 vowels.

# %%
print (len('aeiou'))
# Out:
# 5

# %%
newword = 'oxygen'
counter=0
for char in newword:
    counter = counter + 1
    print(counter,":", char)
# Out:
# 1 : o
# 2 : x
# 3 : y
# 4 : g
# 5 : e
# 6 : n

# %%
for counter, char in enumerate(newword):
    counter +=1
    print(counter, ':',char)
# Out:
# 1 : o
# 2 : x
# 3 : y
# 4 : g
# 5 : e
# 6 : n

# %%
odds = [1, 3, 5, 7]
print('odds are:', odds)
# Out:
# odds are: [1, 3, 5, 7]

# %%
print('first element:', odds[0])
# Out:
# first element: 1

# %%
print ('last element:', odds[len(odds)-1])
# Out:
# last element: 7

# %%
print('last element:', odds[-2])
# Out:
# last element: 5

# %%
names = ['Curie', 'Darwing', 'Turing']
print ('names in list originally:', names)
# Out:
# names in list originally: ['Curie', 'Darwing', 'Turing']

# %%
names[1] = 'Darwin'
print ('new names in list', names)
# Out:
# new names in list ['Curie', 'Darwin', 'Turing']

# %%
salsa = ['peppers', 'onions', 'cilantro', 'tomatoes']
print(salsa)
my_salsa = salsa
print (my_salsa)
# Out:
# ['peppers', 'onions', 'cilantro', 'tomatoes']
# ['peppers', 'onions', 'cilantro', 'tomatoes']

# %%
print(enumerate(salsa))
print(enumerate(my_salsa))
# Out:
# <enumerate object at 0x7f209d361f50>
# <enumerate object at 0x7f209d3bb370>

# %%
x = [['pepper', 'zuchinni', 'onion'],
    ['cabbage', 'lettuce','garlic'],
    ['apple', 'banana', 'pear']]

# %%
# extracting a new nested list with just the first sublist
print ([x[0]])
# Out:
# [['pepper', 'zuchinni', 'onion']]

# %%
# extract a new single list object
print(x[0])
# Out:
# ['pepper', 'zuchinni', 'onion']

# %%
# just character string of pepper
print(x[0][0])
# Out:
# pepper

# %%
sample_ages = [10, 12.5, 'unknown']

# %%
for ages in sample_ages:
    print(ages)
# Out:
# 10
# 12.5
# unknown

# %%
print(odds)
# Out:
# [1, 3, 5, 7]

# %%
odds.append(9)

# %%
print(odds)
# Out:
# [1, 3, 5, 7, 9]

# %%
odds.pop()
print(odds)
# Out:
# [1, 3, 5, 7]

# %%
odds.pop(0)
print(odds)
# Out:
# [3, 5, 7]

# %%
odds.reverse()
print(odds)
# Out:
# [7, 5, 3]

# %%
odds_in_order = []
length_of_odds = len(odds)-1
for ii in range(0, len(odds)):
    odds_in_order.append(odds[length_of_odds-ii])
    
print(odds_in_order)
# Out:
# [3, 5, 7]

# %%
odds = [1, 3, 5, 7]
primes = odds
primes.append(2)
print('primes:', primes)
print('odds:', odds)
# Out:
# primes: [1, 3, 5, 7, 2]
# odds: [1, 3, 5, 7, 2]

# %%
binomial_name = "drosophila melanogaster"
genus = binomial_name[0:10]
print("genus:", genus)

species=binomial_name[11:23]
print(species)
# Out:
# genus: drosophila
# melanogaster

# %%
date = "Monday 3 February 2020"
day = date[0:6]
print(day)
# Out:
# Monday

# %%
months = ["jan", "feb", "march", "april", "may", "june", "july", "aug", "sept", "oct", "nov", "dec"]
last_4_months = months[8:]
print(months[-5:-1])
# Out:
# ['aug', 'sept', 'oct', 'nov']

# %%
num = 42
if num > 100:
    print('greater')
elif num == num:
    print('equal to')
elif num == 42:
    print('youve solved the mystery')
else:
    print('not greater')
# Out:
# equal to

# %%
## operators
+
-
=
/
*
==
!=
>
<
>=
<=
%
# Out:
#   File "<ipython-input-84-f5af5ac8f565>", line 2
#     +
#      ^
# SyntaxError: invalid syntax

# %%
# find squares for forst 10 even numbers
squares_nums=[i * i for i in range (20) if i % 2 == 0]
print(squares_nums)
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]
